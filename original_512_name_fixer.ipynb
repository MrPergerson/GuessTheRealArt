# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt;
import seaborn as sns;
import os;
import time;
from PIL import Image;
from tqdm import tqdm;
import shutil;
# %matplotlib inline

# %%
originals_path = './famous-art-512-sq/'

# %%
df = pd.DataFrame(os.listdir(originals_path))
df.columns = ['file_names']
df.head()
# Out:
#                                           file_names
# 0  Adolph-Von-Menzel-The-Flute-Concert-at-Sanssou...
# 1  Agnolo-Bronzino-Venus-Cupid-and-Time-Allegory-...
# 2  Albert-Bierstadt-Among-the-Sierra-Nevada-Mount...
# 3        Albert-Bierstadt-Deer-in-a-Clearing-S-2.jpg
# 4            Albert-Bierstadt-Forest-Sunrise-S-2.jpg

# %%
files_to_rename = df[df['file_names'].apply(lambda x: len(x.split('_')) > 1)]
files_to_rename
# Out:
#                                             file_names
# 11   Albert-Edelfelt-The-Artist_s-Son-Erik-in-his-P...
# 16   Albrecht-Durer-Portrait-of-a-Young-Venetian-Wo...
# 35              Andrew_Wyeth-Christina_s_World-S-2.jpg
# 38       Andy-Warhol-Campbell_S-Soup-Can-beef--S-2.jpg
# 39      Andy-Warhol-Campbell_S-Soup-Can-onion--S-2.jpg
# ..                                                 ...
# 873  Vincent-Van-Gogh-Vincent_s-Bedroom-in-Arles-4-...
# 877  Vincent_Van_Gogh-Bowl_with_Peonies_and_Roses-S...
# 878  Vincent_Van_Gogh-Branches_with_Almond_Blossom-...
# 879                    Vincent_Van_Gogh-Irises-S-2.jpg
# 880         Vincent_Van_Gogh-Willows_at_Sunset-S-2.jpg
#
# [66 rows x 1 columns]

# %%
new_names = []
for i in files_to_rename['file_names']:
    new_names.append('+'.join(i.split('_')));
new_names
# Out:
# ['Albert-Edelfelt-The-Artist+s-Son-Erik-in-his-Pram-S-2.jpg',
#  'Albrecht-Durer-Portrait-of-a-Young-Venetian-Woman-S+002-2.jpg',
#  'Andrew+Wyeth-Christina+s+World-S-2.jpg',
#  'Andy-Warhol-Campbell+S-Soup-Can-beef--S-2.jpg',
#  'Andy-Warhol-Campbell+S-Soup-Can-onion--S-2.jpg',
#  'Andy+Warhol-Marilyn-S-2.jpg',
#  'Arshile-Gorky-The-Liver-is-the-Cock+s-Comb--S-2.jpg',
#  'Claes+Oldenburg-Lipstick+-+74+-S-2.jpg',
#  'Claes+Oldenburg-Split+button-S-2.jpg',
#  'Claes+Oldenburg-Store+poster-S-2.jpg',
#  'Claude-Monet-The-Pont-de-l+Europe-Gare-Saint-Lazare-S-2.jpg',
#  'Claude+Monet-le+bassin+aux+nympheas-S-2.jpg',
#  'Edgar-Degas-The-Dance-Class-S+002-2.jpg',
#  'EdouardManet-Olympia+Museed+Orsay+Paris(131x190CM)(1863)-S-2.jpg',
#  'EdouardManet-Theabsinthedrinker+nycarlsbergglyptotek+co(1859-2.jpg',
#  'Edvard-Munch-The-Scream-S+002-2.jpg',
#  'Edvard+Munch-Kiss-S-2.jpg',
#  'Edward+Hopper-Nighthawks+The+Art+Institute+of+Chicago+Chica--2.jpg',
# ...

# %%
files_to_rename['new_filenames'] = new_names;
files_to_rename['new_filenames'].head()
# Out:
# 0    Albert-Edelfelt-The-Artist+s-Son-Erik-in-his-P...
# 1    Albrecht-Durer-Portrait-of-a-Young-Venetian-Wo...
# 2               Andrew+Wyeth-Christina+s+World-S-2.jpg
# 3        Andy-Warhol-Campbell+S-Soup-Can-beef--S-2.jpg
# 4       Andy-Warhol-Campbell+S-Soup-Can-onion--S-2.jpg
# Name: new_filenames, dtype: object

# %%
files_to_rename = files_to_rename.reset_index(drop = True)

# %%
files_to_rename[files_to_rename['new_filenames'].apply(lambda x: len(x.split('_')) > 1)]
# Out:
# Empty DataFrame
# Columns: [file_names, new_filenames]
# Index: []

# %%
'''
to_rename = '.\\to_rename\\';
rename_lst = pd.Series(os.listdir(to_rename));
rename_lst[:5]
'''
# Out:
# "\nto_rename = '.\\to_rename\\';\nrename_lst = pd.Series(os.listdir(to_rename));\nrename_lst[:5]\n"

# %%
#rename_to = rename_lst.apply(lambda x: x.split('_')[0] + '--02_' + '_'.join(x.split('_')[1:]))

# %%
for i in range(len(files_to_rename)):
    filepath = originals_path + files_to_rename['file_names'][i];
    filename_to = originals_path + files_to_rename['new_filenames'][i];
    os.rename(src = filepath, dst = filename_to)

# %% [markdown]
# ## Fixing Generated File Names as well \<sigh\>

# %%
genned_path = './processed/'

# %%
df = pd.DataFrame(os.listdir(genned_path))
df.columns = ['file_names']
df.head()
# Out:
#                                           file_names
# 0  Adolph-Von-Menzel-The-Flute-Concert-at-Sanssou...
# 1  Adolph-Von-Menzel-The-Flute-Concert-at-Sanssou...
# 2  Adolph-Von-Menzel-The-Flute-Concert-at-Sanssou...
# 3  Adolph-Von-Menzel-The-Flute-Concert-at-Sanssou...
# 4  Adolph-Von-Menzel-The-Flute-Concert-at-Sanssou...

# %%
df['file_names'].unique()
# Out:
# array(['Adolph-Von-Menzel-The-Flute-Concert-at-Sanssouci-sketch--S_Anime_15.JPG',
#        'Adolph-Von-Menzel-The-Flute-Concert-at-Sanssouci-sketch--S_Barn_11.JPG',
#        'Adolph-Von-Menzel-The-Flute-Concert-at-Sanssouci-sketch--S_Bike_11.JPG',
#        ..., 'Alfred-Sisley-Foggy-Morning-Voisins-S_Horse_9.jpg',
#        'Alfred-Sisley-Foggy-Morning-Voisins-S_Lake_9.jpg',
#        'Alfred-Sisley-Foggy-Morning-Voisins-S_Sports_13.jpg'],
#       dtype=object)

# %%
files_to_rename_genned = df[df['file_names'].apply(lambda x: len(x.split('_')[:-2]) > 1)]
#df[df['file_names'].apply(lambda x: len(x.split('_')[:-2]) > 1)]
files_to_rename_genned
# Out:
# Empty DataFrame
# Columns: [file_names]
# Index: []

# %%
files_to_rename_genned['id'] = list(files_to_rename_genned.index);
files_to_rename_genned = files_to_rename_genned.reset_index(drop = True)
files_to_rename_genned
# Out:
# C:\Users\Shahbaz\AppData\Local\Temp\ipykernel_30012\1814963230.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   files_to_rename_genned['id'] = list(files_to_rename_genned.index);
#                                             file_names    id
# 0    Albert-Edelfelt-The-Artist_s-Son-Erik-in-his-P...   724
# 1    Albert-Edelfelt-The-Artist_s-Son-Erik-in-his-P...   725
# 2    Albert-Edelfelt-The-Artist_s-Son-Erik-in-his-P...   726
# 3    Albert-Edelfelt-The-Artist_s-Son-Erik-in-his-P...   727
# 4    Albert-Edelfelt-The-Artist_s-Son-Erik-in-his-P...   728
# ..                                                 ...   ...
# 127  Albrecht-Durer-Portrait-of-a-Young-Venetian-Wo...  1048
# ...

# %%
#files_to_rename_genned
new_names_genned = []
for i in range(len(files_to_rename_genned)):
    #print(files_to_rename_genned.iloc[i, 0].split('_')[:-2])
    #print('.'.join(files_to_rename_genned.iloc[i, 0].split('_')[:-2]))
    #print ('_'.join(files_to_rename_genned.iloc[i, 0].split('_')[1:]), '\n')
    first_temp = '+'.join(files_to_rename_genned.iloc[i, 0].split('_')[:-2])
    second_temp = '_'.join(files_to_rename_genned.iloc[i, 0].split('_')[1:])
    new_name = first_temp + '.' + second_temp
    #print (new_name)
    new_names_genned.append(new_name)
    
new_names_genned
# Out:
# ['Albert-Edelfelt-The-Artist+s-Son-Erik-in-his-Pram-S.s-Son-Erik-in-his-Pram-S_Anime_13.JPG',
#  'Albert-Edelfelt-The-Artist+s-Son-Erik-in-his-Pram-S.s-Son-Erik-in-his-Pram-S_Barn_12.JPG',
#  'Albert-Edelfelt-The-Artist+s-Son-Erik-in-his-Pram-S.s-Son-Erik-in-his-Pram-S_Bike_7.JPG',
#  'Albert-Edelfelt-The-Artist+s-Son-Erik-in-his-Pram-S.s-Son-Erik-in-his-Pram-S_blue_10.JPG',
#  'Albert-Edelfelt-The-Artist+s-Son-Erik-in-his-Pram-S.s-Son-Erik-in-his-Pram-S_Books_14.JPG',
#  'Albert-Edelfelt-The-Artist+s-Son-Erik-in-his-Pram-S.s-Son-Erik-in-his-Pram-S_Bridge_13.JPG',
#  'Albert-Edelfelt-The-Artist+s-Son-Erik-in-his-Pram-S.s-Son-Erik-in-his-Pram-S_Bus_15.JPG',
#  'Albert-Edelfelt-The-Artist+s-Son-Erik-in-his-Pram-S.s-Son-Erik-in-his-Pram-S_Captivating_11.JPG',
#  'Albert-Edelfelt-The-Artist+s-Son-Erik-in-his-Pram-S.s-Son-Erik-in-his-Pram-S_Car_11.JPG',
#  'Albert-Edelfelt-The-Artist+s-Son-Erik-in-his-Pram-S.s-Son-Erik-in-his-Pram-S_Cat_8.JPG',
# ...

# %%
files_to_rename_genned ['new_filename'] = new_names_genned;
files_to_rename_genned.head()
# Out:
#                                           file_names   id  \
# 0  Albert-Edelfelt-The-Artist_s-Son-Erik-in-his-P...  724
# 1  Albert-Edelfelt-The-Artist_s-Son-Erik-in-his-P...  725
# 2  Albert-Edelfelt-The-Artist_s-Son-Erik-in-his-P...  726
# 3  Albert-Edelfelt-The-Artist_s-Son-Erik-in-his-P...  727
# 4  Albert-Edelfelt-The-Artist_s-Son-Erik-in-his-P...  728
#
#                                         new_filename
# 0  Albert-Edelfelt-The-Artist+s-Son-Erik-in-his-P...
# 1  Albert-Edelfelt-The-Artist+s-Son-Erik-in-his-P...
# 2  Albert-Edelfelt-The-Artist+s-Son-Erik-in-his-P...
# 3  Albert-Edelfelt-The-Artist+s-Son-Erik-in-his-P...
# 4  Albert-Edelfelt-The-Artist+s-Son-Erik-in-his-P...

# %%
for i in range(len(files_to_rename_genned)):
    filepath = genned_path + files_to_rename_genned['file_names'][i];
    filename_to = genned_path + files_to_rename_genned['new_filename'][i];
    os.rename(src = filepath, dst = filename_to)

# %%
files_to_rename
# Out:
#                                            file_names  \
# 0   Albert-Edelfelt-The-Artist_s-Son-Erik-in-his-P...
# 1   Albrecht-Durer-Portrait-of-a-Young-Venetian-Wo...
# 2              Andrew_Wyeth-Christina_s_World-S-2.jpg
# 3       Andy-Warhol-Campbell_S-Soup-Can-beef--S-2.jpg
# 4      Andy-Warhol-Campbell_S-Soup-Can-onion--S-2.jpg
# ..                                                ...
# 61  Vincent-Van-Gogh-Vincent_s-Bedroom-in-Arles-4-...
# 62  Vincent_Van_Gogh-Bowl_with_Peonies_and_Roses-S...
# 63  Vincent_Van_Gogh-Branches_with_Almond_Blossom-...
# 64                    Vincent_Van_Gogh-Irises-S-2.jpg
# 65         Vincent_Van_Gogh-Willows_at_Sunset-S-2.jpg
#
#                                         new_filenames
# 0   Albert-Edelfelt-The-Artist.s-Son-Erik-in-his-P...
# 1   Albrecht-Durer-Portrait-of-a-Young-Venetian-Wo...
# 2              Andrew.Wyeth-Christina.s.World-S-2.jpg
# 3       Andy-Warhol-Campbell.S-Soup-Can-beef--S-2.jpg
# ...
